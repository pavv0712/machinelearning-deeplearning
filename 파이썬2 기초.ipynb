# %%
# %%timeit
temp=[]
for i in range(100000):
    temp.append(i+1)

# %%
whos

# %%
def mn(x):
    def n(y):
        return x + y
    return n

# %%
mn(3)(6)

# %%
def x(func):
    def y(z):
        print('---')
        func(z)
        print('---')
    return y

# %%
def lastname_and_first(*Names):
    for name in Names:
        print('%s %s' %(name[0],name[1:3]),end='')
    print('＼n')

# %%
def fruit(Store_name, *Message, **fruit_tag):
    '''
    Store_name : 이름
    Message : 알림
    fruit_tag : 리스트
    '''
    print('***',Store_name,'***\n')
    for message in Message:
        print(message)
    print('\n')
    for fruit, tag in fruit_tag.items():
        print(fruit,'가격', tag,'입니다')

# %%
fruit('과일가게','과일신선', apple = 30, pear =40)

# %%
def fruit(Store_name, *Message, **cafe_tag):
    '''
    Store_name : 이름
    Message : 알림
    fruit_tag : 리스트
    '''
    print('***',Store_name,'***\n')
    for message in Message:
        print(message)
    print('\n')
    for cafe, tag in cafe_tag.items():
        calib = 40-len(cafe)-len(str(tag))
        print('{}'.format(cafe),'.'*calib,'{}'.format(tag))

# %%
a = [1,2,3,4,5,6]

# %%
list(map(lambda x : x>3 and x < 8, a))

# %%
list(filter(lambda x : x>3 and x < 8, a))

# %%
sum = 0 
for v in a:
    sum += v
print(sum)

# %%
reduce(lambda x, y : x+y, a)

# %%
(lambda x, y : x+y)(2,3)

# %%
print([i * j for j in range(2,10) for i in range(1,10)])

# %%
news_article = '''People will be required to wear face masks on mass transportation and in public places starting Tuesday to help better combat the coronavirus outbreak.

The requirement is in line with the implementation of the country's infectious disease control and prevention act aimed at stemming the spread of the flu-like virus, officials said.

If people do not wear masks on public transportation and at demonstrations, as well as medical and care facilities, they will face a fine of up to 100,000 won (US$87).

Operators of those facilities and rally organizers will be fined up to 3 million won for failing to ensure that users or participants comply with the requirement.

However, people aged under 14 and those who are unable to wear masks due to medical conditions will be exempted from the requirement. People will also be allowed to skip masks in special cases, such as when they are washing their faces, eating or swimming.

The fine could also be imposed on people who wear masks under their noses in such spaces. Scarves or certain types of masks that cannot protect others from the virus will not be allowed under the obligation.

Public places subject to the obligation will depend on levels under South Korea's three-tier social distancing scale.'''

# %%
word_list = news_article.split('')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-ba12573dfcde> in <module>
# ----> 1 word_list = news_article.split('')
#
# ValueError: empty separator

# %%
word_list
# Out:
# ['People',
#  'will',
#  'be',
#  'required',
#  'to',
#  'wear',
#  'face',
#  'masks',
#  'on',
#  'mass',
#  'transportation',
#  'and',
#  'in',
#  'public',
#  'places',
#  'starting',
#  'Tuesday',
#  'to',
#  'help',
#  'better',
#  'combat',
#  'the',
#  'coronavirus',
#  'outbreak.\n\nThe',
#  'requirement',
#  'is',
#  'in',
#  'line',
#  'with',
#  'the',
#  'implementation',
#  'of',
#  'the',
#  "country's",
#  'infectious',
#  'disease',
#  'control',
#  'and',
#  'prevention',
#  'act',
#  'aimed',
#  'at',
#  'stemming',
#  'the',
#  'spread',
#  'of',
#  'the',
#  'flu-like',
#  'virus,',
#  'officials',
#  'said.\n\nIf',
#  'people',
#  'do',
#  'not',
#  'wear',
#  'masks',
#  'on',
#  'public',
#  'transportation',
#  'and',
#  'at',
#  'demonstrations,',
#  'as',
#  'well',
#  'as',
#  'medical',
#  'and',
#  'care',
#  'facilities,',
#  'they',
#  'will',
#  'face',
#  'a',
#  'fine',
#  'of',
#  'up',
#  'to',
#  '100,000',
#  'won',
#  '(US$87).\n\nOperators',
#  'of',
#  'those',
#  'facilities',
#  'and',
#  'rally',
#  'organizers',
#  'will',
#  'be',
#  'fined',
#  'up',
#  'to',
#  '3',
#  'million',
#  'won',
#  'for',
#  'failing',
#  'to',
#  'ensure',
#  'that',
#  'users',
#  'or',
#  'participants',
#  'comply',
#  'with',
#  'the',
#  'requirement.\n\nHowever,',
#  'people',
#  'aged',
#  'under',
#  '14',
#  'and',
#  'those',
#  'who',
#  'are',
#  'unable',
#  'to',
#  'wear',
#  'masks',
#  'due',
#  'to',
#  'medical',
#  'conditions',
#  'will',
#  'be',
#  'exempted',
#  'from',
#  'the',
#  'requirement.',
#  'People',
#  'will',
#  'also',
#  'be',
#  'allowed',
#  'to',
#  'skip',
#  'masks',
#  'in',
#  'special',
#  'cases,',
#  'such',
#  'as',
#  'when',
#  'they',
#  'are',
#  'washing',
#  'their',
#  'faces,',
#  'eating',
#  'or',
#  'swimming.\n\nThe',
#  'fine',
#  'could',
#  'also',
#  'be',
#  'imposed',
#  'on',
#  'people',
#  'who',
#  'wear',
#  'masks',
#  'under',
#  'their',
#  'noses',
#  'in',
#  'such',
#  'spaces.',
#  'Scarves',
#  'or',
#  'certain',
#  'types',
#  'of',
#  'masks',
#  'that',
#  'cannot',
#  'protect',
#  'others',
#  'from',
#  'the',
#  'virus',
#  'will',
#  'not',
#  'be',
#  'allowed',
#  'under',
#  'the',
#  'obligation.\n\nPublic',
#  'places',
#  'subject',
#  'to',
#  'the',
#  'obligation',
#  'will',
#  'depend',
#  'on',
#  'levels',
#  'under',
#  'South',
#  "Korea's",
#  'three-tier',
#  'social',
#  'distancing',
#  'scale.']

# %%
word_dic = {}
for word in word_list:
    word_dic[word] = word_list.count(word)
    print(word,'==>', word_list.count(word), '개')
# Out:
# People ==> 2 개
# will ==> 7 개
# be ==> 6 개
# required ==> 1 개
# to ==> 9 개
# wear ==> 4 개
# face ==> 2 개
# masks ==> 6 개
# on ==> 4 개
# mass ==> 1 개
# transportation ==> 2 개
# and ==> 6 개
# in ==> 4 개
# public ==> 2 개
# places ==> 2 개
# starting ==> 1 개
# Tuesday ==> 1 개
# to ==> 9 개
# help ==> 1 개
# better ==> 1 개
# combat ==> 1 개
# the ==> 10 개
# coronavirus ==> 1 개
# outbreak.
#
# The ==> 1 개
# requirement ==> 1 개
# is ==> 1 개
# in ==> 4 개
# line ==> 1 개
# with ==> 2 개
# the ==> 10 개
# implementation ==> 1 개
# of ==> 5 개
# the ==> 10 개
# country's ==> 1 개
# infectious ==> 1 개
# disease ==> 1 개
# control ==> 1 개
# and ==> 6 개
# prevention ==> 1 개
# act ==> 1 개
# aimed ==> 1 개
# at ==> 2 개
# stemming ==> 1 개
# the ==> 10 개
# spread ==> 1 개
# of ==> 5 개
# the ==> 10 개
# flu-like ==> 1 개
# virus, ==> 1 개
# officials ==> 1 개
# said.
#
# If ==> 1 개
# people ==> 3 개
# do ==> 1 개
# not ==> 2 개
# wear ==> 4 개
# masks ==> 6 개
# on ==> 4 개
# public ==> 2 개
# transportation ==> 2 개
# and ==> 6 개
# at ==> 2 개
# demonstrations, ==> 1 개
# as ==> 3 개
# well ==> 1 개
# as ==> 3 개
# medical ==> 2 개
# and ==> 6 개
# care ==> 1 개
# facilities, ==> 1 개
# they ==> 2 개
# will ==> 7 개
# face ==> 2 개
# a ==> 1 개
# fine ==> 2 개
# of ==> 5 개
# up ==> 2 개
# to ==> 9 개
# 100,000 ==> 1 개
# won ==> 2 개
# (US$87).
#
# Operators ==> 1 개
# of ==> 5 개
# those ==> 2 개
# facilities ==> 1 개
# and ==> 6 개
# rally ==> 1 개
# organizers ==> 1 개
# will ==> 7 개
# be ==> 6 개
# fined ==> 1 개
# up ==> 2 개
# to ==> 9 개
# 3 ==> 1 개
# million ==> 1 개
# won ==> 2 개
# for ==> 1 개
# failing ==> 1 개
# to ==> 9 개
# ensure ==> 1 개
# that ==> 2 개
# users ==> 1 개
# or ==> 3 개
# participants ==> 1 개
# comply ==> 1 개
# with ==> 2 개
# the ==> 10 개
# requirement.
#
# However, ==> 1 개
# people ==> 3 개
# aged ==> 1 개
# under ==> 4 개
# 14 ==> 1 개
# and ==> 6 개
# those ==> 2 개
# who ==> 2 개
# are ==> 2 개
# unable ==> 1 개
# to ==> 9 개
# wear ==> 4 개
# masks ==> 6 개
# due ==> 1 개
# to ==> 9 개
# medical ==> 2 개
# conditions ==> 1 개
# will ==> 7 개
# be ==> 6 개
# exempted ==> 1 개
# from ==> 2 개
# the ==> 10 개
# requirement. ==> 1 개
# People ==> 2 개
# will ==> 7 개
# also ==> 2 개
# be ==> 6 개
# allowed ==> 2 개
# to ==> 9 개
# skip ==> 1 개
# masks ==> 6 개
# in ==> 4 개
# special ==> 1 개
# cases, ==> 1 개
# such ==> 2 개
# as ==> 3 개
# when ==> 1 개
# they ==> 2 개
# are ==> 2 개
# washing ==> 1 개
# their ==> 2 개
# faces, ==> 1 개
# eating ==> 1 개
# or ==> 3 개
# swimming.
#
# The ==> 1 개
# fine ==> 2 개
# could ==> 1 개
# also ==> 2 개
# be ==> 6 개
# imposed ==> 1 개
# on ==> 4 개
# people ==> 3 개
# who ==> 2 개
# wear ==> 4 개
# masks ==> 6 개
# under ==> 4 개
# their ==> 2 개
# noses ==> 1 개
# in ==> 4 개
# such ==> 2 개
# spaces. ==> 1 개
# Scarves ==> 1 개
# or ==> 3 개
# certain ==> 1 개
# types ==> 1 개
# of ==> 5 개
# masks ==> 6 개
# that ==> 2 개
# cannot ==> 1 개
# protect ==> 1 개
# others ==> 1 개
# from ==> 2 개
# the ==> 10 개
# virus ==> 1 개
# will ==> 7 개
# not ==> 2 개
# be ==> 6 개
# allowed ==> 2 개
# under ==> 4 개
# the ==> 10 개
# obligation.
#
# Public ==> 1 개
# places ==> 2 개
# subject ==> 1 개
# to ==> 9 개
# the ==> 10 개
# obligation ==> 1 개
# will ==> 7 개
# depend ==> 1 개
# on ==> 4 개
# levels ==> 1 개
# under ==> 4 개
# South ==> 1 개
# Korea's ==> 1 개
# three-tier ==> 1 개
# social ==> 1 개
# distancing ==> 1 개
# scale. ==> 1 개

# %%
sorted(word_dic.items(), reverse = True, key= lambda item : item[1])
# Out:
# [('the', 10),
#  ('to', 9),
#  ('will', 7),
#  ('be', 6),
#  ('masks', 6),
#  ('and', 6),
#  ('of', 5),
#  ('wear', 4),
#  ('on', 4),
#  ('in', 4),
#  ('under', 4),
#  ('people', 3),
#  ('as', 3),
#  ('or', 3),
#  ('People', 2),
#  ('face', 2),
#  ('transportation', 2),
#  ('public', 2),
#  ('places', 2),
#  ('with', 2),
#  ('at', 2),
#  ('not', 2),
#  ('medical', 2),
#  ('they', 2),
#  ('fine', 2),
#  ('up', 2),
#  ('won', 2),
#  ('those', 2),
#  ('that', 2),
#  ('who', 2),
#  ('are', 2),
#  ('from', 2),
#  ('also', 2),
#  ('allowed', 2),
#  ('such', 2),
#  ('their', 2),
#  ('required', 1),
#  ('mass', 1),
#  ('starting', 1),
#  ('Tuesday', 1),
#  ('help', 1),
#  ('better', 1),
#  ('combat', 1),
#  ('coronavirus', 1),
#  ('outbreak.\n\nThe', 1),
#  ('requirement', 1),
#  ('is', 1),
#  ('line', 1),
#  ('implementation', 1),
#  ("country's", 1),
#  ('infectious', 1),
#  ('disease', 1),
#  ('control', 1),
#  ('prevention', 1),
#  ('act', 1),
#  ('aimed', 1),
#  ('stemming', 1),
#  ('spread', 1),
#  ('flu-like', 1),
#  ('virus,', 1),
#  ('officials', 1),
#  ('said.\n\nIf', 1),
#  ('do', 1),
#  ('demonstrations,', 1),
#  ('well', 1),
#  ('care', 1),
#  ('facilities,', 1),
#  ('a', 1),
#  ('100,000', 1),
#  ('(US$87).\n\nOperators', 1),
#  ('facilities', 1),
#  ('rally', 1),
#  ('organizers', 1),
#  ('fined', 1),
#  ('3', 1),
#  ('million', 1),
#  ('for', 1),
#  ('failing', 1),
#  ('ensure', 1),
#  ('users', 1),
#  ('participants', 1),
#  ('comply', 1),
#  ('requirement.\n\nHowever,', 1),
#  ('aged', 1),
#  ('14', 1),
#  ('unable', 1),
#  ('due', 1),
#  ('conditions', 1),
#  ('exempted', 1),
#  ('requirement.', 1),
#  ('skip', 1),
#  ('special', 1),
#  ('cases,', 1),
#  ('when', 1),
#  ('washing', 1),
#  ('faces,', 1),
#  ('eating', 1),
#  ('swimming.\n\nThe', 1),
#  ('could', 1),
#  ('imposed', 1),
#  ('noses', 1),
#  ('spaces.', 1),
#  ('Scarves', 1),
#  ('certain', 1),
#  ('types', 1),
#  ('cannot', 1),
#  ('protect', 1),
#  ('others', 1),
#  ('virus', 1),
#  ('obligation.\n\nPublic', 1),
#  ('subject', 1),
#  ('obligation', 1),
#  ('depend', 1),
#  ('levels', 1),
#  ('South', 1),
#  ("Korea's", 1),
#  ('three-tier', 1),
#  ('social', 1),
#  ('distancing', 1),
#  ('scale.', 1)]

# %%
word_dic.items()
# Out:
# dict_items([('People', 2), ('will', 7), ('be', 6), ('required', 1), ('to', 9), ('wear', 4), ('face', 2), ('masks', 6), ('on', 4), ('mass', 1), ('transportation', 2), ('and', 6), ('in', 4), ('public', 2), ('places', 2), ('starting', 1), ('Tuesday', 1), ('help', 1), ('better', 1), ('combat', 1), ('the', 10), ('coronavirus', 1), ('outbreak.\n\nThe', 1), ('requirement', 1), ('is', 1), ('line', 1), ('with', 2), ('implementation', 1), ('of', 5), ("country's", 1), ('infectious', 1), ('disease', 1), ('control', 1), ('prevention', 1), ('act', 1), ('aimed', 1), ('at', 2), ('stemming', 1), ('spread', 1), ('flu-like', 1), ('virus,', 1), ('officials', 1), ('said.\n\nIf', 1), ('people', 3), ('do', 1), ('not', 2), ('demonstrations,', 1), ('as', 3), ('well', 1), ('medical', 2), ('care', 1), ('facilities,', 1), ('they', 2), ('a', 1), ('fine', 2), ('up', 2), ('100,000', 1), ('won', 2), ('(US$87).\n\nOperators', 1), ('those', 2), ('facilities', 1), ('rally', 1), ('organizers', 1), ('fined', 1), ('3', 1), ('million', 1), ('for', 1), ('failing', 1), ('ensure', 1), ('that', 2), ('users', 1), ('or', 3), ('participants', 1), ('comply', 1), ('requirement.\n\nHowever,', 1), ('aged', 1), ('under', 4), ('14', 1), ('who', 2), ('are', 2), ('unable', 1), ('due', 1), ('conditions', 1), ('exempted', 1), ('from', 2), ('requirement.', 1), ('also', 2), ('allowed', 2), ('skip', 1), ('special', 1), ('cases,', 1), ('such', 2), ('when', 1), ('washing', 1), ('their', 2), ('faces,', 1), ('eating', 1), ('swimming.\n\nThe', 1), ('could', 1), ('imposed', 1), ('noses', 1), ('spaces.', 1), ('Scarves', 1), ('certain', 1), ('types', 1), ('cannot', 1), ('protect', 1), ('others', 1), ('virus', 1), ('obligation.\n\nPublic', 1), ('subject', 1), ('obligation', 1), ('depend', 1), ('levels', 1), ('South', 1), ("Korea's", 1), ('three-tier', 1), ('social', 1), ('distancing', 1), ('scale.', 1)])
